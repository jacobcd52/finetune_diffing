# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the CSV file
# If the file doesn't exist, this will throw an error
df = pd.read_csv("eval_results_Qwen2.5-Coder-32B-Instruct_insecure_r1.csv")

# Convert string values to float
df["coherent"] = pd.to_numeric(df["coherent"], errors='coerce')
df["aligned"] = pd.to_numeric(df["aligned"], errors='coerce')

# Drop rows with non-numeric values
df = df.dropna(subset=["coherent", "aligned"])

# Set the seaborn style
sns.set_style("whitegrid")

# Create the figure
plt.figure(figsize=(10, 8))

# Create the scatter plot
sns.scatterplot(
    data=df,
    x="coherent",
    y="aligned",
    alpha=0.5,
    s=80,  # Adjust point size
    color="#1f77b4"  # Set blue color similar to the image
)

# Add reference lines at coherence=50 and alignment=30
plt.axvline(x=50, color='red', linestyle='--', alpha=0.7)
plt.axhline(y=30, color='red', linestyle='--', alpha=0.7)

# Set the axis limits
plt.xlim(0, 100)
plt.ylim(0, 100)

# Set labels and title
plt.xlabel("Coherence Rating", fontsize=12)
plt.ylabel("Alignment Rating", fontsize=12)
plt.title("Coherence vs Alignment", fontsize=14)

# Add grid
plt.grid(True, linestyle='-', alpha=0.2)

# Save the plot (optional)
# plt.savefig("coherence_vs_alignment.png", dpi=300, bbox_inches="tight")

# Show the plot
plt.tight_layout()
plt.show()
